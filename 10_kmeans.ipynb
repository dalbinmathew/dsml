# %% [markdown]
# # K Means Clustering
#
# K-means is a popular unsupervised machine learning algorithm used for clustering tasks. It partitions a dataset into K distinct, non-overlapping groups or clusters based on feature similarity. The algorithm aims to group data points in such a way that the points in each cluster are more similar to each other than to those in other clusters.

# %% [markdown]
# ### Algorithm
#
# The K-means algorithm follows these basic steps:
#
# 1. **Initialization**:
#    - Choose the number of clusters $ K $.
#    - Randomly initialize $ K $ centroids (cluster centers) from the data points.
#
# 2. **Assignment Step**:
#    - For each data point, assign it to the nearest centroid based on a distance metric (usually Euclidean distance). This creates $ K $ clusters.
#
# 3. **Update Step**:
#    - Calculate the new centroids by taking the mean of all the data points assigned to each cluster.
#
# 4. **Convergence Check**:
#    - Repeat the assignment and update steps until the centroids no longer change significantly or a maximum number of iterations is reached.

# %% [markdown]
# ### Mathematical Formulation
# The K-means algorithm aims to **minimize the total intra-cluster variance**, which can be defined as:
#
# $$
# J = \sum_{i=1}^{K} \sum_{x_j \in C_i} \| x_j - \mu_i \|^2
# $$
#
# Where:
# - $ J $ is the objective function to minimize (sum of squared distances).
# - $ K $ is the number of clusters.
# - $ C_i $ is the set of data points in cluster $ i $.
# - $ x_j $ is a data point in cluster $ i $.
# - $ \mu_i $ is the centroid of cluster $ i $.

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# %%
# make_blobs() outputs a tuple (data, cluster_labels)
data, _ = make_blobs(n_samples=300)

# %%
model = KMeans(random_state=42, n_clusters=5, n_init='auto')
model.fit(data)
# Out:
# KMeans(n_clusters=5, n_init='auto', random_state=42)

# %%
labels = model.labels_

# Stores the coordinates of the centroids for these 5 clusters
centroids = model.cluster_centers_

# %%
# Plotting the first two features of the data and coloring the points based on the cluster they belong to
plt.scatter(data[:, 0], data[:, 1], c=labels, cmap='viridis', marker='o', alpha=0.6)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.title('K-Means')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.legend(list(labels))
plt.show()

# %%
model.predict([[2, -4], [6, 6], [6, -2]])
# Out:
# array([1, 0, 1])

# %% [markdown]
# ### Choosing the Number of Clusters ($K$)
# Choosing the right number of clusters $ K $ can be challenging. Several methods can help determine an optimal value:
#
# - **Elbow Method**: Plot the total within-cluster variance (inertia) against the number of clusters. The point where the curve bends (the "elbow") indicates a good choice for $ K $.
#
# - **Silhouette Score**: Measures how similar a point is to its own cluster compared to other clusters. A higher score indicates better-defined clusters.

# %% [markdown]
# | **Advantages of K-means** | **Limitations of K-means** | **Applications of K-means** |
# |---------------------------|----------------------------|-----------------------------|
# | - **Simplicity**: The algorithm is easy to implement and understand. | - **Choosing K**: The requirement to specify the number of clusters in advance can be problematic. | - **Customer Segmentation**: Grouping customers based on purchasing behavior for targeted marketing. |
# | - **Efficiency**: K-means is computationally efficient and can handle large datasets. | - **Sensitivity to Initialization**: Random initialization of centroids can lead to different clustering results. Using methods like K-means++ can improve initialization. | - **Image Compression**: Reducing the number of colors in an image by clustering pixel colors. |
# | - **Scalability**: Works well with a large number of samples and dimensions. | - **Assumption of Spherical Clusters**: K-means assumes that clusters are spherical and equally sized, which may not always be the case. | - **Anomaly Detection**: Identifying outliers in data based on their distance from cluster centroids. |
# | | - **Outlier Sensitivity**: K-means is sensitive to outliers, which can skew the cluster centroids and affect the clustering result. | |
